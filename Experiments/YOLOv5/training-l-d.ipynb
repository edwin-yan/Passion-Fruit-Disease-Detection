# %%
import torch
print(f"Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Using torch 1.9.1+rocm4.2 (Device 738c)

# %%
#Multi GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 4 train.py --img 512 --batch 256 --epochs 600 --workers 120 --data passion_fruit.yaml --weights yolov5x.pt --sync-bn

#Multi GPU - from stratch
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 4 train.py --img 512 --batch 320 --epochs 900 --workers 120 --data passion_fruit.yaml --weights '' --cfg yolov5l.yaml --sync-bn

#Single GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python train.py --img 512 --batch 32 --epochs 50 --data passion_fruit.yaml --weights yolov5s.pt
# Out:
# /home/shaohyan/anaconda3/envs/tf38/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# train: weights=, cfg=yolov5l.yaml, data=passion_fruit.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=900, batch_size=320, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=True, workers=120, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 e685c48 torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for 4 nodes.
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     43080  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 468 layers, 46149064 parameters, 46149064 gradients, 108.0 GFLOPs
#
# Scaled weight_decay = 0.0025
# optimizer: SGD with parameter groups 101 weight, 104 weight (no decay), 104 bias
# Using SyncBatchNorm()
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# train: WARNING: ../datasets/Train/images/ID_Y1XECFL7.jpg: 1 duplicate labels removed
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# val: Scanning '../datasets/Val/labels.cache' images and labels... 303 found, 0 m
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 3.95, Best Possible Recall (BPR) = 1.0000
# Image sizes 512 train, 512 val
# Using 80 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 900 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   0%|                                                     | 0/9 [00:00<?, ?it/s]MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
#      0/899     1.91G     0.109   0.02561   0.03802       191       512:  11%| | Reducer buckets have been rebuilt in this iteration.
#      0/899     2.34G    0.1085   0.02583   0.03781        96       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00087      0.252   0.000641   0.000121
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/899     27.4G   0.08082   0.02799    0.0364        73       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0011      0.348   0.000938   0.000187
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/899     30.4G    0.0781   0.02826   0.03492        83       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00106      0.333   0.000944   0.000201
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/899     30.4G   0.07858   0.02575   0.03452        78       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00129      0.365    0.00103   0.000213
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/899     30.4G   0.07686   0.02816   0.03435       106       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00113      0.322    0.00103   0.000225
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/899     30.4G   0.07677   0.02802   0.03412        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00117      0.329    0.00102   0.000214
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/899     30.4G    0.0772   0.02751   0.03419        78       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0013      0.342    0.00116    0.00023
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/899     30.4G   0.07559   0.02759   0.03411       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00123      0.337    0.00118   0.000231
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/899     30.4G   0.07545   0.02813   0.03409        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00153      0.367    0.00127   0.000244
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/899     30.4G   0.07588   0.02933   0.03357        97       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00129      0.333    0.00109   0.000218
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/899     30.4G   0.07452   0.02679   0.03485        78       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00168      0.398     0.0016   0.000324
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/899     30.4G   0.07618   0.02892   0.03435        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00229      0.512    0.00286    0.00051
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/899     30.4G   0.07378   0.02934   0.03308        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00309      0.727     0.0078    0.00127
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/899     30.4G   0.07393   0.02789   0.03377        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00319       0.74     0.0114    0.00205
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/899     30.4G   0.06997   0.02978   0.03281       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.342      0.229     0.0305    0.00916
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/899     30.4G   0.06792   0.03032   0.03271       109       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0597      0.218     0.0377    0.00778
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/899     30.4G   0.06621   0.02829   0.03126        84       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0283      0.204     0.0142    0.00286
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/899     30.4G   0.06363     0.028   0.03118        79       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.07      0.149     0.0383    0.00773
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/899     30.4G   0.06268   0.02784   0.03107        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0443       0.12     0.0272    0.00645
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/899     30.4G   0.06276   0.02595   0.02881        75       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.185      0.214      0.106     0.0341
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/899     30.4G   0.06022   0.02588   0.02963        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0834      0.185     0.0572     0.0202
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/899     30.4G   0.05846   0.02519    0.0281        93       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.184      0.313      0.126     0.0378
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/899     30.4G   0.05743    0.0249   0.02797        85       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0916     0.0755     0.0194    0.00558
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/899     30.4G   0.05527   0.02414   0.02753        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.128      0.339     0.0749     0.0311
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/899     30.4G   0.05474   0.02398   0.02581        83       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.133      0.233     0.0725     0.0383
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     25/899     30.4G   0.05348   0.02487   0.02568        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.122      0.124     0.0393     0.0171
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     26/899     30.4G    0.0545   0.02363   0.02572        79       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0686     0.0778     0.0113    0.00364
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     27/899     30.4G   0.05278    0.0221    0.0251        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0979     0.0464     0.0119    0.00385
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     28/899     30.4G   0.05166    0.0215   0.02491        73       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0101     0.0157    0.00131   0.000311
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     29/899     30.4G   0.04911   0.02245   0.02502        91       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.105      0.127     0.0369     0.0142
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     30/899     30.4G   0.04996    0.0213   0.02413        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.021    0.00823   0.000339   7.59e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     31/899     30.4G   0.04927   0.02208   0.02358       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.135      0.195     0.0654     0.0215
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     32/899     30.4G     0.048   0.02118   0.02117        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.272      0.251       0.13     0.0645
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     33/899     30.4G   0.04817   0.02249   0.02246       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.427     0.0301     0.0201     0.0104
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     34/899     30.4G   0.04686   0.02023   0.02148        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00964     0.0475    0.00201   0.000625
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     35/899     30.4G   0.04766    0.0213   0.02022       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0347     0.0383     0.0096     0.0042
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     36/899     30.4G   0.04675   0.01989   0.01951        73       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.267      0.166      0.102     0.0409
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     37/899     30.4G   0.04614   0.02023   0.01856        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.527      0.184      0.168     0.0898
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     38/899     30.4G   0.04666    0.0195    0.0179        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.61      0.274      0.258       0.14
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     39/899     30.4G   0.04495   0.01944   0.01836       105       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.457      0.294      0.243       0.14
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     40/899     30.4G   0.04605   0.01875   0.01608        84       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.319      0.225      0.162     0.0841
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     41/899     30.4G   0.04761    0.0197   0.01381       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.369      0.254       0.19     0.0988
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     42/899     30.4G   0.04562   0.01864   0.01496        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.686      0.323      0.338      0.171
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     43/899     30.4G   0.04503   0.01935   0.01631        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.246      0.305      0.178     0.0584
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     44/899     30.4G   0.04679   0.01926   0.01315        93       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.408      0.228      0.171     0.0774
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     45/899     30.4G   0.04574   0.01896   0.01367        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.454      0.301       0.25      0.132
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     46/899     30.4G   0.04362   0.01817   0.01303        91       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.668      0.334      0.324      0.208
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     47/899     30.4G   0.04232   0.01702   0.01384        73       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.584      0.359      0.357      0.215
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     48/899     30.4G   0.04056    0.0174   0.01127        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.473      0.323      0.302      0.161
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     49/899     30.4G   0.04262   0.01841   0.01196       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.521      0.323      0.293      0.181
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     50/899     30.4G   0.04108   0.01675   0.01093        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.729      0.389      0.407      0.275
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     51/899     30.4G    0.0428   0.01658  0.009709        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.703      0.345      0.357      0.228
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     52/899     30.4G   0.03987    0.0166  0.009844        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.48      0.342      0.299      0.179
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     53/899     30.4G   0.04285   0.01682   0.01141        75       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.667      0.374      0.385      0.218
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     54/899     30.4G   0.04025   0.01657   0.01024        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.694      0.367      0.383      0.244
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     55/899     30.4G   0.04016   0.01731  0.008663       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.747       0.38      0.418      0.291
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     56/899     30.4G   0.03989    0.0166  0.008211        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.817      0.376      0.409      0.287
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     57/899     30.4G   0.03852   0.01624  0.008585        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.711      0.346      0.378      0.242
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     58/899     30.4G    0.0397   0.01735  0.008848       105       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.224      0.287      0.204      0.111
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     59/899     30.4G   0.04004   0.01677  0.009391        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.661      0.337      0.352      0.244
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     60/899     30.4G   0.03712    0.0165  0.008073        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.661      0.369      0.391      0.248
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     61/899     30.4G   0.03669   0.01588  0.009392        77       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.827      0.367      0.399      0.262
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     62/899     30.4G   0.03779   0.01577  0.007662       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.781      0.439      0.445      0.318
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     63/899     30.4G   0.03723   0.01575  0.007794        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.392       0.32      0.201      0.138
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     64/899     30.4G   0.03858   0.01618  0.008086        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.56      0.325      0.275        0.2
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     65/899     30.4G   0.03541   0.01571  0.008365        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.819      0.427      0.437      0.327
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     66/899     30.4G   0.03474   0.01548  0.007356       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.596      0.331      0.335      0.221
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     67/899     30.4G   0.03596   0.01574  0.007741        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.758      0.411      0.438      0.303
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     68/899     30.4G   0.03448   0.01438  0.007312        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.747      0.417      0.424      0.308
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     69/899     30.4G   0.03468   0.01445  0.007018        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.898      0.415      0.446      0.311
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     70/899     30.4G   0.03818   0.01575  0.007435        82       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.752      0.403       0.41      0.243
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     71/899     30.4G   0.03701    0.0148  0.006278        79       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.836      0.396      0.432      0.265
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     72/899     30.4G   0.03498   0.01454  0.005416        96       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.876      0.431      0.449      0.321
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     73/899     30.4G   0.03678   0.01495  0.006526        86       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.813       0.42      0.436      0.292
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     74/899     30.4G   0.03642    0.0152  0.006303        86       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.747      0.376      0.397      0.242
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     75/899     30.4G   0.03512    0.0145  0.005728        93       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.868      0.426      0.449      0.339
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     76/899     30.4G   0.03467   0.01462  0.005931        71       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.711      0.422      0.436       0.31
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     77/899     30.4G    0.0342   0.01434  0.006687        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.84      0.401      0.429      0.312
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     78/899     30.4G   0.03435    0.0147   0.00496        91       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.713      0.381      0.398       0.29
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     79/899     30.4G    0.0319   0.01421  0.005354        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.832      0.416      0.448      0.291
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     80/899     30.4G   0.03177   0.01353  0.006476        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.921      0.432      0.464      0.346
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     81/899     30.4G   0.03449   0.01439  0.006286        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.82      0.425      0.443      0.315
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     82/899     30.4G   0.03373   0.01452  0.004751        73       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.938      0.434      0.462      0.347
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     83/899     30.4G    0.0316   0.01347  0.005573        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.84      0.452      0.463      0.345
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     84/899     30.4G   0.03237   0.01444  0.005134        93       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.823      0.439       0.45      0.317
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     85/899     30.4G    0.0321   0.01424  0.006111        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.897       0.43      0.453      0.322
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     86/899     30.4G   0.03244   0.01353  0.006304        85       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.731      0.375      0.401      0.274
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     87/899     30.4G   0.03238   0.01309  0.005733       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.744      0.416      0.358      0.242
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     88/899     30.4G   0.03133   0.01359  0.004702        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.751      0.373      0.364      0.272
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     89/899     30.4G   0.03262   0.01324  0.005473        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.783      0.406      0.423      0.334
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     90/899     30.4G   0.03082   0.01355  0.005299        76       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.784      0.373      0.405      0.297
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     91/899     30.4G   0.03018   0.01308  0.004487        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.812       0.44      0.457      0.339
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     92/899     30.4G   0.03042   0.01285  0.005172        71       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.914      0.439      0.462      0.359
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     93/899     30.4G   0.03015    0.0127  0.005014        58       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.836      0.463       0.46      0.357
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     94/899     30.4G   0.02992    0.0132  0.005601        86       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.739       0.44      0.448      0.335
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     95/899     30.4G   0.03096   0.01449  0.006175       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.773       0.39      0.428      0.333
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     96/899     30.4G    0.0295   0.01326  0.005963        82       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.869      0.426      0.446       0.33
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     97/899     30.4G   0.02731   0.01382  0.005693       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.802      0.414      0.428      0.334
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     98/899     30.4G    0.0297   0.01325  0.005871        93       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.868      0.438      0.453      0.351
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     99/899     30.4G   0.02777   0.01256  0.005336        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.82      0.433      0.456      0.377
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    100/899     30.4G   0.02847   0.01246  0.005475        85       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.88      0.438      0.457      0.329
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    101/899     30.4G   0.02857   0.01336   0.00521        83       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.835      0.442      0.438      0.326
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    102/899     30.4G   0.02683   0.01286  0.005223        97       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.762      0.411      0.426      0.319
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    103/899     30.4G   0.02726   0.01238  0.004582       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.651      0.396      0.416      0.323
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    104/899     30.4G   0.02784   0.01278  0.004578       115       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.779      0.384      0.424      0.342
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    105/899     30.4G   0.02684   0.01314  0.004182        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375        0.8      0.365      0.418      0.333
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    106/899     30.4G   0.02722   0.01255  0.004958       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.839      0.369      0.378      0.298
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    107/899     30.4G   0.02706   0.01203  0.005907        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.801      0.272       0.31      0.226
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    108/899     30.4G   0.02793    0.0127  0.004135        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.697      0.228      0.235       0.17
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    109/899     30.4G   0.02659   0.01236  0.004878        82       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.809      0.428      0.438      0.347
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    110/899     30.4G   0.02644   0.01227  0.004109       109       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.77      0.372      0.398      0.306
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    111/899     30.4G   0.02595   0.01203   0.00574        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.741      0.336      0.382      0.292
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    112/899     30.4G   0.02662   0.01252  0.005943        91       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.762      0.329       0.39      0.316
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    113/899     30.4G   0.02613   0.01219  0.004256        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.791      0.369       0.41      0.311
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    114/899     30.4G   0.02637   0.01216  0.005063        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.803      0.396      0.419      0.329
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    115/899     30.4G   0.02591   0.01222  0.005199       101       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.862      0.415      0.449      0.337
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    116/899     30.4G   0.02518   0.01241   0.00418        96       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.868      0.433      0.456      0.366
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    117/899     30.4G   0.02507   0.01222  0.003907        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.836      0.421      0.442      0.344
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    118/899     30.4G    0.0251    0.0118  0.004723        71       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.745      0.411      0.431      0.329
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    119/899     30.4G   0.02499    0.0127  0.003873       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.852      0.415      0.456      0.354
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    120/899     30.4G   0.02336    0.0121   0.00418        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.856      0.425      0.456       0.38
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    121/899     30.4G    0.0244    0.0116  0.004071        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.874      0.449       0.47      0.394
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    122/899     30.4G   0.02481   0.01156  0.004582        85       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.926      0.436      0.475      0.393
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    123/899     30.4G     0.024   0.01114  0.003954        84       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.792       0.42      0.448      0.366
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    124/899     30.4G   0.02307   0.01104  0.004062        67       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.867      0.417      0.454      0.375
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    125/899     30.4G   0.02523    0.0117  0.003464        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.774      0.344      0.395      0.331
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    126/899     30.4G   0.02359   0.01136  0.003878        85       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.881       0.46      0.475       0.39
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    127/899     30.4G   0.02375   0.01126  0.003036        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.885      0.456      0.475      0.401
#
# ...
#                  all        303        375      0.952      0.463       0.53      0.486
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    449/899     30.4G   0.01408  0.008104   0.00128        83       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.955       0.46      0.531      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    450/899     30.4G   0.01424  0.008059  0.001284        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.948      0.462      0.532      0.486
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    451/899     30.4G    0.0139  0.008085  0.000936        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.94      0.462      0.529      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    452/899     30.4G   0.01352  0.007911  0.001595       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.952      0.464      0.521      0.471
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    453/899     30.4G   0.01431  0.007996  0.001528        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.938      0.468      0.519      0.473
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    454/899     30.4G   0.01404  0.007787  0.001011        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.935      0.466      0.516       0.47
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    455/899     30.4G   0.01508  0.008014 0.0007814        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.949      0.465       0.52      0.475
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    456/899     30.4G   0.01421  0.007801  0.001028        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.951      0.464      0.527       0.48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    457/899     30.4G   0.01353   0.00738 0.0009582        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.947      0.468      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    458/899     30.4G   0.01396  0.007807  0.001433       121       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.936       0.47      0.531      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    459/899     30.4G   0.01371  0.007407  0.001542        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.955       0.47       0.53      0.482
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    460/899     30.4G     0.014  0.007479  0.001478        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.962      0.468       0.53      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    461/899     30.4G   0.01411  0.007638  0.001336       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.957      0.465      0.526      0.481
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    462/899     30.4G   0.01461  0.007888  0.001213       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.963      0.464      0.522      0.472
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    463/899     30.4G    0.0146  0.007656   0.00117        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.955      0.465      0.529      0.479
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    464/899     30.4G   0.01358  0.007765  0.001483        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.958      0.462      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    465/899     30.4G   0.01397  0.007589  0.001093        97       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.953      0.462      0.534       0.48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    466/899     30.4G   0.01406  0.007824  0.001115       101       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.922      0.467      0.531      0.476
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    467/899     30.4G   0.01419  0.007954  0.001406        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.951      0.469      0.528      0.481
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    468/899     30.4G   0.01368  0.007794  0.001288        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.948      0.466      0.526      0.476
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    469/899     30.4G    0.0137  0.007879 0.0008832        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.93       0.47      0.529      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    470/899     30.4G   0.01376  0.007698 0.0007635        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.465      0.535      0.489
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    471/899     30.4G   0.01389  0.007657 0.0009813        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.932      0.467      0.533      0.486
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    472/899     30.4G   0.01358  0.007528 0.0009161        93       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.942      0.468      0.531      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    473/899     30.4G   0.01323  0.007467  0.001211        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.959      0.465      0.527      0.481
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    474/899     30.4G   0.01306  0.007154 0.0008446        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.927      0.472      0.527      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    475/899     30.4G   0.01379  0.007546 0.0006279        82       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.95      0.464      0.531      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    476/899     30.4G    0.0137  0.007466 0.0007988        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.955      0.462      0.528      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    477/899     30.4G   0.01374  0.007683 0.0009408        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.946      0.461      0.524      0.482
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    478/899     30.4G   0.01346  0.007794  0.001061        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.932      0.468      0.526       0.48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    479/899     30.4G   0.01348  0.007478  0.001157        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.984      0.457      0.531      0.489
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    480/899     30.4G   0.01301  0.007377    0.0011        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.955      0.465      0.533      0.486
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    481/899     30.4G    0.0133  0.007232  0.001079        79       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.93       0.47      0.533      0.488
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    482/899     30.4G   0.01331  0.007627 0.0009391        83       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.964      0.465       0.53      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    483/899     30.4G   0.01416  0.007742  0.001242       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.959      0.465      0.523       0.48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    484/899     30.4G    0.0139  0.007486  0.001337        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.949      0.463       0.52      0.475
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    485/899     30.4G   0.01369  0.007763  0.001527        85       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.946      0.465      0.522      0.476
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    486/899     30.4G   0.01296  0.007422  0.001817        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.947      0.465      0.524      0.478
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    487/899     30.4G   0.01333  0.007473  0.001536       119       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.969      0.452      0.519      0.474
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    488/899     30.4G   0.01331  0.007681  0.001033       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.976      0.461      0.513      0.469
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    489/899     30.4G   0.01332  0.007707  0.001051        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.947      0.463      0.526       0.48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    490/899     30.4G   0.01368  0.007357  0.001047        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.957      0.459       0.53      0.482
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    491/899     30.4G   0.01295  0.007939  0.001186        78       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.971      0.463      0.528       0.48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    492/899     30.4G   0.01332  0.007436  0.001761        84       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.947      0.463      0.527      0.481
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    493/899     30.4G   0.01352  0.007775  0.001449        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.957      0.465      0.525      0.477
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    494/899     30.4G   0.01349   0.00776  0.001183        80       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.959      0.461      0.524      0.481
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    495/899     30.4G   0.01373  0.007633   0.00102        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.954      0.463      0.531      0.488
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    496/899     30.4G   0.01317  0.007465  0.000776       115       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.962      0.467       0.53      0.487
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    497/899     30.4G   0.01294  0.007251  0.001217        86       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.962      0.465       0.53      0.486
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    498/899     30.4G    0.0144   0.00755  0.001981       197       512:  56%|▌|

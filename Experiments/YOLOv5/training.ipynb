# %%
import torch
print(f"Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Using torch 1.9.1+rocm4.2 (Device 738c)

# %%
#Multi GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 4 train.py --img 512 --batch 256 --epochs 600 --workers 120 --data passion_fruit.yaml --weights yolov5x.pt --sync-bn

#Multi GPU - from stratch
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 4 train.py --img 512 --batch 320 --epochs 1500 --workers 120 --data passion_fruit.yaml --weights '' --cfg yolov5l.yaml --hyp hyp.scratch-med.yaml --sync-bn

#Single GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python train.py --img 512 --batch 32 --epochs 50 --data passion_fruit.yaml --weights yolov5s.pt
# Out:
# /home/shaohyan/anaconda3/envs/tf38/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# train: weights=, cfg=yolov5l.yaml, data=passion_fruit.yaml, hyp=hyp.scratch-med.yaml, epochs=1500, batch_size=320, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=True, workers=120, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 e685c48 torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for 4 nodes.
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.1, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     43080  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 468 layers, 46149064 parameters, 46149064 gradients, 108.0 GFLOPs
#
# Scaled weight_decay = 0.0025
# optimizer: SGD with parameter groups 101 weight, 104 weight (no decay), 104 bias
# Using SyncBatchNorm()
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# train: WARNING: ../datasets/Train/images/ID_Y1XECFL7.jpg: 1 duplicate labels removed
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# train: Scanning '../datasets/Train/labels.cache' images and labels... 2698 found
# val: Scanning '../datasets/Val/labels.cache' images and labels... 303 found, 0 m
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 3.95, Best Possible Recall (BPR) = 1.0000
# Image sizes 512 train, 512 val
# Using 80 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 1500 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   0%|                                                     | 0/9 [00:00<?, ?it/s]MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
#     0/1499     1.91G    0.1097   0.01967   0.02425       241       512:  11%| | Reducer buckets have been rebuilt in this iteration.
#     0/1499     2.34G    0.1085   0.01951   0.02353       111       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    9.9e-05     0.0672    7.8e-05   1.45e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     1/1499     27.4G   0.09007   0.02215   0.02256       109       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000636      0.223   0.000464   0.000106
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     2/1499     30.4G   0.08849   0.02218   0.02174       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00046      0.113   0.000289   5.46e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     3/1499     30.4G   0.08721   0.02096   0.02133        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000684       0.21    0.00061    0.00012
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     4/1499     30.4G    0.0868    0.0228   0.02118       125       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000454       0.16   0.000416   7.56e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     5/1499     30.4G   0.08667   0.02325   0.02134       116       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00071      0.171   0.000569   8.68e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     6/1499     30.4G   0.08589   0.02267   0.02103       109       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000454      0.135   0.000499   8.81e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     7/1499     30.4G   0.08731   0.02209   0.02113        91       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000322     0.0926   0.000502   0.000149
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     8/1499     30.4G   0.08479   0.02247   0.02108       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000626      0.192   0.000438   8.26e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     9/1499     30.4G   0.08535   0.02259   0.02119       118       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000214     0.0773   0.000288   5.46e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    10/1499     30.4G   0.08469   0.02161   0.02105        78       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000307      0.075   0.000208   5.57e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    11/1499     30.4G    0.0826   0.02229   0.02098       101       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000399     0.0727    0.00024   7.43e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    12/1499     30.4G   0.07605   0.02484   0.02101       116       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00243       0.12    0.00161   0.000261
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    13/1499     30.4G   0.07125   0.02559   0.02097       113       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0278     0.0795    0.00766    0.00112
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    14/1499     30.4G   0.06978   0.02608   0.02091       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.125      0.126     0.0393    0.00706
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    15/1499     30.4G   0.06792   0.02485   0.02075       105       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0496      0.171     0.0199     0.0052
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    16/1499     30.4G   0.06779   0.02341     0.021        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.101     0.0486     0.0117      0.003
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    17/1499     30.4G   0.06704   0.02329   0.02072        96       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.118      0.116     0.0317    0.00947
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    18/1499     30.4G   0.06475   0.02344   0.02072       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0692     0.0735     0.0142     0.0035
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    19/1499     30.4G   0.06685   0.02323   0.02082       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000307    0.00249   5.87e-05   8.69e-06
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    20/1499     30.4G   0.06311   0.02243   0.02083       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.139      0.157     0.0491     0.0134
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    21/1499     30.4G   0.06291   0.02221   0.02038       101       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0674      0.112     0.0198    0.00444
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    22/1499     30.4G   0.06251   0.02195   0.02041       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00868     0.0178   0.000972   0.000183
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    23/1499     30.4G   0.05961    0.0223   0.02031       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00089     0.0503   0.000285   5.06e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    24/1499     30.4G   0.06176   0.02269   0.02046       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375    0.00229     0.0274    0.00064   0.000131
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    25/1499     30.4G   0.05711   0.02097    0.0202       101       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0291      0.121    0.00572    0.00157
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    26/1499     30.4G   0.05762   0.02157   0.01982       134       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0492     0.0315    0.00281   0.000726
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    27/1499     30.4G   0.05865   0.01918   0.01963        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000484    0.00249   5.61e-05   1.12e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    28/1499     30.4G   0.05596   0.02091   0.01997        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0223     0.0493    0.00227   0.000579
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    29/1499     30.4G   0.05601   0.01963    0.0197        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0472     0.0782     0.0122    0.00379
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    30/1499     30.4G   0.05375   0.02022   0.01925       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0165      0.031    0.00065   0.000274
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    31/1499     30.4G    0.0574    0.0198   0.01927       125       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0372    0.00518   0.000379   0.000161
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    32/1499     30.4G   0.05407    0.0199   0.01855       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0442     0.0743    0.00806    0.00339
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    33/1499     30.4G   0.05378   0.02039    0.0184       130       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.142      0.146     0.0437     0.0165
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    34/1499     30.4G   0.04964   0.01824   0.01885        88       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0295      0.042     0.0034   0.000763
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    35/1499     30.4G    0.0529   0.01819   0.01766       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0319      0.029    0.00292   0.000504
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    36/1499     30.4G   0.05443   0.01874   0.01764        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0641     0.0237     0.0053    0.00151
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    37/1499     30.4G   0.04958    0.0183   0.01762       109       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0493     0.0438    0.00689    0.00172
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    38/1499     30.4G   0.05053   0.01815   0.01743       120       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0525     0.0852      0.011     0.0043
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    39/1499     30.4G   0.05455   0.01783   0.01759       119       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0125     0.0126    0.00137    0.00048
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    40/1499     30.4G   0.05398   0.01804   0.01764       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0243     0.0394    0.00459    0.00199
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    41/1499     30.4G   0.05266   0.01884   0.01749       122       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0539     0.0205    0.00183   0.000523
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    42/1499     30.4G    0.0481   0.01701   0.01633       112       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0837     0.0561    0.00827     0.0033
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    43/1499     30.4G   0.05001   0.01601   0.01692        72       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.105     0.0486     0.0202    0.00755
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    44/1499     30.4G    0.0505   0.01689   0.01769       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0941     0.0598     0.0111    0.00491
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    45/1499     30.4G   0.04908   0.01686   0.01718       119       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.109     0.0839     0.0283     0.0107
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    46/1499     30.4G   0.05308   0.01668   0.01792       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.105      0.169     0.0522     0.0222
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    47/1499     30.4G   0.04934   0.01712   0.01733       133       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0757     0.0879     0.0245    0.00762
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    48/1499     30.4G   0.04804   0.01656   0.01641       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.235      0.179     0.0995     0.0535
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    49/1499     30.4G   0.04703   0.01672   0.01563       133       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.281      0.334      0.234      0.122
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    50/1499     30.4G   0.04612   0.01621   0.01615       120       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.186      0.129     0.0556     0.0336
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    51/1499     30.4G   0.04491   0.01592   0.01617        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.445      0.367      0.302      0.196
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    52/1499     30.4G   0.04718   0.01546   0.01569       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.376      0.355      0.233      0.165
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    53/1499     30.4G   0.04761   0.01561   0.01607       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.201      0.105     0.0661     0.0327
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    54/1499     30.4G   0.04482    0.0165   0.01526       139       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0271     0.0158    0.00631     0.0025
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    55/1499     30.4G   0.04858   0.01543    0.0154       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0398      0.029    0.00956    0.00399
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    56/1499     30.4G   0.04711   0.01574   0.01506       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0517     0.0312     0.0067    0.00307
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    57/1499     30.4G   0.04565    0.0145   0.01525        71       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.264      0.168     0.0861     0.0465
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    58/1499     30.4G   0.04687   0.01602   0.01458       116       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.213      0.204     0.0849     0.0514
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    59/1499     30.4G   0.04718   0.01583   0.01418       130       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.106     0.0575     0.0207    0.00728
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    60/1499     30.4G   0.04605   0.01543   0.01456       126       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.185     0.0809     0.0498     0.0171
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    61/1499     30.4G   0.04552   0.01532    0.0141       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.291      0.136     0.0824     0.0562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    62/1499     30.4G    0.0418    0.0146   0.01353       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.356      0.327      0.272      0.174
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    63/1499     30.4G   0.04164   0.01422   0.01338       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.51      0.318      0.295      0.185
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    64/1499     30.4G   0.04578   0.01505   0.01305       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.47      0.371      0.334      0.169
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    65/1499     30.4G   0.04349   0.01435   0.01302        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.482      0.339      0.315      0.187
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    66/1499     30.4G   0.04335   0.01422   0.01194       113       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.159      0.118      0.071     0.0472
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    67/1499     30.4G   0.04439   0.01416   0.01232       116       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.498      0.284      0.255      0.151
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    68/1499     30.4G   0.04478   0.01429   0.01225        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.199      0.114     0.0648      0.036
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    69/1499     30.4G   0.04096   0.01444   0.01101       109       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.187      0.104     0.0724     0.0414
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    70/1499     30.4G   0.04093   0.01402   0.01123       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.512      0.294      0.274      0.185
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    71/1499     30.4G   0.04301   0.01445   0.01168       112       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.462      0.119        0.1     0.0461
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    72/1499     30.4G   0.03941   0.01491   0.01218        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.537      0.347      0.349      0.222
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    73/1499     30.4G   0.04116   0.01439    0.0113        97       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.332      0.263      0.192        0.1
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    74/1499     30.4G   0.04158   0.01355  0.009597        96       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.377     0.0156    0.00276   0.000822
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    75/1499     30.4G   0.04068   0.01343   0.01053       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0834     0.0365     0.0208    0.00632
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    76/1499     30.4G   0.04048   0.01281   0.01003        84       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.244     0.0939      0.065     0.0304
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    77/1499     30.4G   0.03671   0.01335  0.008925       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.352      0.251      0.191      0.124
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    78/1499     30.4G   0.03962   0.01348  0.009603        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.67      0.355      0.356      0.212
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    79/1499     30.4G    0.0377   0.01359   0.00961       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.75      0.337      0.382      0.272
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    80/1499     30.4G   0.03788   0.01377   0.01098       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303          0          0          0          0          0
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    81/1499     30.4G   0.03919     0.014   0.01062        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375   0.000514     0.0103   0.000136   3.46e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    82/1499     30.4G   0.03709    0.0139  0.009401       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.204     0.0587     0.0399     0.0245
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    83/1499     30.4G   0.03693   0.01325  0.008844       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.29      0.172      0.134     0.0772
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    84/1499     30.4G   0.03957   0.01291  0.008321       121       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.208      0.181      0.115     0.0681
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    85/1499     30.4G   0.03711   0.01225  0.008335        82       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.664      0.303      0.318      0.204
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    86/1499     30.4G   0.03518   0.01328  0.007662       127       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.701      0.366      0.362      0.251
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    87/1499     30.4G    0.0363   0.01287  0.008198       119       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.703      0.388      0.384      0.254
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    88/1499     30.4G   0.03925   0.01314  0.008371       137       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0385      0.045     0.0102    0.00379
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    89/1499     30.4G   0.03826   0.01237  0.006946        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.228     0.0836     0.0615     0.0321
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    90/1499     30.4G   0.03725   0.01341  0.007412        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.568      0.338       0.34      0.233
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    91/1499     30.4G   0.03617   0.01249  0.006755       105       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.718      0.351      0.365      0.264
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    92/1499     30.4G   0.03469    0.0128  0.007097       105       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.794      0.388      0.418      0.307
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    93/1499     30.4G   0.03471   0.01306  0.007635       122       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.691      0.385      0.402      0.274
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    94/1499     30.4G   0.03503    0.0122  0.007255       120       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.828      0.422      0.443      0.359
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    95/1499     30.4G   0.03437    0.0118  0.006856       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.848      0.414      0.427      0.356
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    96/1499     30.4G   0.03214   0.01189  0.006351        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.34      0.341      0.245      0.178
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    97/1499     30.4G   0.03211   0.01253  0.006666       134       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.763      0.438      0.446      0.333
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    98/1499     30.4G   0.03148   0.01134  0.005935        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.775      0.394      0.415      0.298
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    99/1499     30.4G   0.03196   0.01144  0.006329       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.901      0.406       0.44      0.308
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   100/1499     30.4G   0.03604   0.01185  0.007685        94       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.806      0.398      0.431      0.286
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   101/1499     30.4G   0.03426   0.01185  0.006718       105       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.774      0.407      0.425       0.29
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   102/1499     30.4G    0.0329   0.01148  0.005747       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.801       0.43      0.438      0.322
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   103/1499     30.4G   0.03164   0.01213  0.006311        96       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.864      0.386      0.431      0.327
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   104/1499     30.4G   0.03357    0.0126  0.007032       117       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.665      0.331      0.318      0.239
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   105/1499     30.4G   0.03098   0.01184  0.006572       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.58      0.266      0.262      0.196
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   106/1499     30.4G   0.03245   0.01191  0.007097       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.491      0.351       0.31      0.201
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   107/1499     30.4G   0.03083    0.0112  0.005575        93       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.886      0.428      0.454      0.357
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   108/1499     30.4G   0.02915   0.01153  0.006206       123       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.674      0.372      0.382      0.271
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   109/1499     30.4G    0.0308   0.01088  0.006205       112       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.46      0.343      0.296        0.2
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   110/1499     30.4G   0.03019   0.01112  0.005887        81       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.354      0.206      0.167      0.106
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   111/1499     30.4G   0.02864   0.01108   0.00539       120       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.495      0.319      0.278      0.193
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   112/1499     30.4G   0.02944   0.01093  0.005607       112       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.718       0.37      0.402      0.292
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   113/1499     30.4G   0.02921   0.01116  0.005158       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.674       0.34      0.342      0.245
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   114/1499     30.4G   0.02939    0.0128   0.01271       134       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303          0          0          0          0          0
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   115/1499     30.4G   0.03106    0.0136  0.009053       114       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303          0          0          0          0          0
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   116/1499     30.4G   0.03071   0.01189  0.007666        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375     0.0441     0.0564    0.00974    0.00521
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   117/1499     30.4G   0.03035   0.01179  0.006853       112       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.109      0.112     0.0455     0.0268
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   118/1499     30.4G    0.0309   0.01258  0.006572       143       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.381      0.197      0.185      0.133
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   119/1499     30.4G   0.02779   0.01174  0.006324       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.646      0.374      0.374      0.274
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   120/1499     30.4G   0.02851   0.01061  0.005551       112       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.611       0.36      0.387      0.295
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   121/1499     30.4G   0.02815   0.01105  0.005772       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.71        0.4      0.425       0.33
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   122/1499     30.4G   0.02855   0.01114  0.005818       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.821      0.422      0.445      0.341
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   123/1499     30.4G   0.02868    0.0113  0.005349       114       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.827      0.416      0.444      0.332
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   124/1499     30.4G   0.02771   0.01093  0.005681       118       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.791      0.445      0.457      0.348
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   125/1499     30.4G    0.0276   0.01046   0.00519        98       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.724      0.349      0.386      0.263
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   126/1499     30.4G   0.02744   0.01035  0.004953        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.824      0.422      0.452      0.347
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   127/1499     30.4G   0.02712   0.01084  0.005192        97       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375        0.9      0.425      0.456      0.353
#
# ...
#                  all        303        375      0.966      0.457      0.531      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1401/1499     30.4G   0.01009  0.005008 0.0006719       114       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.966      0.457      0.532      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1402/1499     30.4G   0.01017  0.004741 0.0005282        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.966      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1403/1499     30.4G   0.01044   0.00531  0.001104       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1404/1499     30.4G   0.01048  0.005113  0.001185       112       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1405/1499     30.4G   0.01004   0.00474 0.0008066        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1406/1499     30.4G   0.01007  0.004866 0.0009279       128       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1407/1499     30.4G   0.01037  0.005145  0.000888       129       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1408/1499     30.4G  0.009986  0.005157 0.0008823       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1409/1499     30.4G    0.0109  0.005096 0.0008927       123       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.983      0.452      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1410/1499     30.4G  0.009797  0.004924  0.001004        92       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.983      0.452      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1411/1499     30.4G  0.009506  0.004825 0.0008236       113       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1412/1499     30.4G  0.009784  0.004796 0.0008362       111       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1413/1499     30.4G  0.009857  0.004842  0.001056       101       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1414/1499     30.4G   0.01002  0.005041  0.001089       130       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1415/1499     30.4G   0.01005  0.004917  0.000727        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1416/1499     30.4G  0.009909  0.004679 0.0009843       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1417/1499     30.4G  0.009839  0.004704 0.0008428       126       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.983      0.452      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1418/1499     30.4G  0.009631  0.004778  0.000599       105       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1419/1499     30.4G  0.009806   0.00459 0.0005957       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1420/1499     30.4G  0.009452   0.00468 0.0006575        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1421/1499     30.4G   0.01014  0.004783 0.0009604        91       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1422/1499     30.4G  0.009713  0.004732  0.000977        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.532      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1423/1499     30.4G  0.009935  0.005024  0.001028       120       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1424/1499     30.4G   0.01053  0.004861 0.0007442        87       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1425/1499     30.4G  0.009965  0.004878 0.0009814       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1426/1499     30.4G   0.00981  0.004601  0.000871       100       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1427/1499     30.4G   0.01043   0.00453 0.0008438        82       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1428/1499     30.4G   0.01004  0.004708 0.0006213       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1429/1499     30.4G   0.01006  0.004805  0.000886       104       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1430/1499     30.4G   0.01043  0.004807 0.0008414        91       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.981      0.452      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1431/1499     30.4G   0.01076  0.005062  0.001439       116       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.982      0.452      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1432/1499     30.4G  0.009739  0.004807 0.0007722       103       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.981      0.452      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1433/1499     30.4G  0.009857   0.00493 0.0009408       106       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.981      0.452      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1434/1499     30.4G   0.01038  0.004464  0.001129       102       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.958      0.457      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1435/1499     30.4G   0.01026  0.004794 0.0009036        90       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.966      0.457      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1436/1499     30.4G  0.009649  0.004646 0.0008508       108       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.966      0.457      0.532      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1437/1499     30.4G   0.01013  0.004759  0.001013        89       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.959      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1438/1499     30.4G  0.009835  0.004553 0.0007827        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1439/1499     30.4G    0.0106  0.004837 0.0007627       107       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.457      0.532      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1440/1499     30.4G   0.00963  0.005171   0.00072       124       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.457      0.533      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1441/1499     30.4G   0.01001  0.004903 0.0008922       110       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.457      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1442/1499     30.4G   0.01019  0.004842 0.0008149       111       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.457      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1443/1499     30.4G  0.009501  0.004703 0.0006793        95       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.959      0.457      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1444/1499     30.4G  0.009625  0.004839 0.0006674       118       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.959      0.457      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1445/1499     30.4G  0.009735  0.004478 0.0008073        86       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.959      0.457      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1446/1499     30.4G    0.0102  0.004666 0.0008787        99       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.457      0.533      0.485
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1447/1499     30.4G   0.01016  0.005047  0.001228       131       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375       0.96      0.457      0.533      0.484
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1448/1499     30.4G  0.009945  0.005181 0.0007285       118       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1449/1499     30.4G  0.009597  0.004868 0.0007853        73       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.967      0.457      0.532      0.483
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1450/1499     30.4G    0.0104   0.00499  0.001031       257       512:  56%|▌|

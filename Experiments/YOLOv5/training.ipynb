# %%
import torch
print(f"Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Using torch 1.9.1+rocm4.2 (Device 738c)

# %%
#Multi GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 4 train.py --img 512 --batch 128 --epochs 100 --data passion_fruit.yaml --weights yolov5x.pt --sync-bn

#Single GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python train.py --img 512 --batch 32 --epochs 50 --data passion_fruit.yaml --weights yolov5s.pt
# Out:
# /home/shaohyan/anaconda3/envs/tf38/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# train: weights=yolov5x.pt, cfg=, data=passion_fruit.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=128, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=True, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 46dc995 torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for 4 nodes.
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5x.pt to yolov5x.pt...
# 100%|████████████████████████████████████████| 166M/166M [00:01<00:00, 88.7MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Conv                      [3, 80, 6, 2, 2]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  8   2259200  models.common.C3                        [320, 320, 8]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  4  19676160  models.common.C3                        [1280, 1280, 4]
#   9                -1  1   4099840  models.common.SPPF                      [1280, 1280, 5]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     53832  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model Summary: 567 layers, 86231272 parameters, 86231272 gradients, 204.2 GFLOPs
#
# Transferred 739/745 items from yolov5x.pt
# Scaled weight_decay = 0.001
# optimizer: SGD with parameter groups 123 weight, 126 weight (no decay), 126 bias
# Using SyncBatchNorm()
# train: Scanning '../datasets/Train/labels.cache' images and labels... 3001 found
# train: WARNING: ../datasets/Train/images/ID_Y1XECFL7.jpg: 1 duplicate labels removed
# train: Scanning '../datasets/Train/labels.cache' images and labels... 3001 found
# train: Scanning '../datasets/Train/labels.cache' images and labels... 3001 found
# train: Scanning '../datasets/Train/labels.cache' images and labels... 3001 found
# val: Scanning '../datasets/Train/labels.cache' images and labels... 3001 found,
# train: WARNING: ../datasets/Train/images/ID_Y1XECFL7.jpg: 1 duplicate labels removed
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 3.93, Best Possible Recall (BPR) = 0.9997
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   0%|                                                    | 0/24 [00:00<?, ?it/s]MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
#       0/99     2.12G    0.1144   0.02172   0.04006        69       512:   4%| | Reducer buckets have been rebuilt in this iteration.
#       0/99     2.39G   0.08425   0.02684   0.03669        45       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.263       0.55      0.278      0.137
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/99       17G   0.05812   0.02274   0.03083        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.306      0.658      0.404      0.214
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/99     18.5G   0.05243   0.01815    0.0249        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.47       0.68       0.56      0.383
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/99     18.5G   0.04896   0.01632   0.01819        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.767      0.727      0.808      0.395
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/99     18.5G   0.04751   0.01477   0.01294        38       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.762       0.82      0.857      0.529
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/99     18.5G   0.04317   0.01359  0.009659        33       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.899      0.837      0.936      0.649
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/99     18.5G   0.04125   0.01322  0.007338        50       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.876      0.731      0.892      0.559
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/99     18.5G   0.04029   0.01241  0.006561        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.78      0.883      0.929      0.699
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/99     18.5G   0.03825   0.01248  0.006818        42       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.914      0.721      0.869      0.626
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/99     18.5G   0.03673   0.01144  0.006491        32       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.778      0.725      0.878      0.671
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/99     18.5G   0.03504   0.01155  0.005898        38       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.912      0.806      0.927      0.727
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/99     18.5G   0.03465   0.01156  0.005608        38       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.666      0.832      0.893      0.684
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/99     18.5G   0.03329   0.01144  0.005378        57       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.952      0.937      0.985      0.745
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/99     18.5G   0.03208   0.01054  0.005066        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.742      0.816      0.881      0.709
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/99     18.5G   0.03075   0.01133   0.00464        47       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.798       0.85      0.924      0.742
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/99     18.5G   0.03051   0.01037  0.004472        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.874      0.831      0.933      0.772
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/99     18.5G    0.0292   0.01014  0.004714        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.956       0.96      0.988      0.848
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/99     18.5G   0.02896  0.009736  0.004515        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.904       0.89      0.963      0.755
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/99     18.5G   0.02831   0.01049  0.004807        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.95      0.929      0.982      0.832
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/99     18.5G   0.02668  0.009269  0.004244        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.948      0.932      0.983      0.818
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      20/99     18.5G   0.02686   0.01011    0.0048        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.795      0.933      0.948        0.8
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      21/99     18.5G   0.02593   0.01007  0.004667        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.888      0.859      0.955       0.81
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      22/99     18.5G    0.0253  0.009346  0.003946        29       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.942      0.944      0.984      0.834
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      23/99     18.5G   0.02582  0.009355  0.003392        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.736      0.882      0.933      0.797
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      24/99     18.5G   0.02545  0.009973  0.004135        48       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.908      0.918      0.971      0.822
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      25/99     18.5G   0.02512   0.00951  0.004476        35       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.815      0.866       0.93      0.811
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      26/99     18.5G   0.02342    0.0101  0.004169        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.959      0.959      0.989      0.841
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      27/99     18.5G   0.02378  0.009323  0.004246        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.957      0.954      0.984      0.858
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      28/99     18.5G   0.02383  0.009485  0.003755        32       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.927      0.885      0.951      0.821
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      29/99     18.5G   0.02323  0.009737  0.004206        43       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.895      0.812      0.952      0.786
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      30/99     18.5G   0.02236  0.009047  0.003441        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.62      0.753      0.758       0.64
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      31/99     18.5G    0.0216  0.009297  0.005134        42       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.917      0.879      0.958      0.823
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      32/99     18.5G   0.02156  0.009698  0.004634        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.824      0.723      0.872      0.741
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      33/99     18.5G   0.02127  0.008758   0.00397        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.571      0.807      0.811      0.682
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      34/99     18.5G   0.02143  0.009965  0.003456        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.829      0.873      0.929      0.787
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      35/99     18.5G   0.02031  0.008943  0.004646        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.755      0.752      0.851      0.736
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      36/99     18.5G   0.02005  0.009812  0.005902        31       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.638      0.781       0.79      0.675
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      37/99     18.5G   0.02062  0.009621    0.0042        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.485      0.789      0.668      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      38/99     18.5G   0.01939  0.009377  0.003741        27       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.92      0.898      0.971      0.847
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      39/99     18.5G   0.01925  0.009467  0.004674        47       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.886      0.864      0.943      0.816
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      40/99     18.5G   0.01889  0.009606  0.004733        47       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.746      0.745       0.86      0.741
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      41/99     18.5G   0.01885  0.009338  0.003968        61       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.774        0.8      0.899      0.765
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      42/99     18.5G   0.01882  0.009521   0.00464        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.89      0.568      0.732      0.623
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      43/99     18.5G   0.01915  0.009163  0.004457        33       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.952      0.933      0.983      0.853
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      44/99     18.5G   0.01885  0.009008  0.003476        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.891      0.847      0.955      0.834
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      45/99     18.5G   0.01821  0.009189  0.004206        32       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.948      0.905      0.978      0.869
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      46/99     18.5G   0.01767  0.008906  0.003468        45       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.938      0.912      0.979      0.871
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      47/99     18.5G   0.01739  0.009393  0.003044        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.796       0.81      0.932      0.824
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      48/99     18.5G   0.01737  0.008622  0.003193        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.89      0.917      0.967      0.848
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      49/99     18.5G   0.01618  0.008444  0.003236        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.927      0.938      0.982      0.883
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      50/99     18.5G   0.01709  0.008565  0.004615        33       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.826      0.835      0.905      0.796
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      51/99     18.5G   0.01664  0.008445  0.003091        42       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.941      0.959      0.987      0.895
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      52/99     18.5G   0.01613  0.008492  0.002566        45       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.957      0.958      0.988      0.895
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      53/99     18.5G   0.01624  0.008201   0.00299        45       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.943      0.929      0.981      0.883
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      54/99     18.5G   0.01503  0.008792  0.003705        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.921      0.912      0.977       0.87
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      55/99     18.5G    0.0157  0.008081  0.002923        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.969       0.97      0.992      0.902
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      56/99     18.5G   0.01504  0.008005  0.002083        38       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.96      0.956      0.991        0.9
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      57/99     18.5G   0.01516  0.008064  0.001937        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.935      0.935      0.983       0.89
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      58/99     18.5G    0.0155  0.008322  0.001988        49       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.959      0.957      0.989      0.896
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      59/99     18.5G   0.01433   0.00795  0.001828        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.954      0.956      0.989      0.899
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      60/99     18.5G   0.01422  0.007512  0.002088        32       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.957      0.955      0.989      0.898
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      61/99     18.5G   0.01429  0.007735  0.001639        35       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.971      0.969      0.991      0.903
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      62/99     18.5G   0.01374  0.007699  0.001857        43       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.963      0.956      0.988      0.906
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      63/99     18.5G   0.01388  0.007359  0.002169        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.967      0.967      0.992      0.911
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      64/99     18.5G   0.01336  0.007455  0.001424        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.968      0.978      0.991       0.91
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      65/99     18.5G   0.01386  0.007515  0.001638        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.952       0.96      0.989      0.904
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      66/99     18.5G   0.01341  0.007528  0.001702        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.962      0.971      0.991      0.911
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      67/99     18.5G   0.01323  0.007502  0.002493        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.97      0.975      0.992      0.918
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      68/99     18.5G   0.01262  0.007116  0.001248        38       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.969      0.983      0.992      0.918
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      69/99     18.5G   0.01351  0.007538  0.001511        52       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.967      0.976      0.991      0.917
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      70/99     18.5G   0.01293  0.007012  0.001368        43       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.966      0.982      0.992      0.916
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      71/99     18.5G   0.01161  0.007053 0.0008394        45       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.967      0.971      0.992      0.918
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      72/99     18.5G   0.01254  0.007134  0.001448        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.981      0.978      0.993      0.923
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      73/99     18.5G   0.01209  0.006824   0.00116        54       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.977      0.985      0.993      0.923
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      74/99     18.5G   0.01139  0.006757  0.001293        28       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.964      0.979      0.992       0.92
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      75/99     18.5G     0.012  0.007284  0.001335        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.972      0.987      0.993      0.923
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      76/99     18.5G   0.01252  0.007073  0.001261        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.976      0.989      0.993      0.927
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      77/99     18.5G    0.0119  0.006824  0.001136        47       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.978      0.985      0.993      0.928
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      78/99     18.5G   0.01172  0.006592 0.0009809        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.973      0.992      0.993      0.928
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      79/99     18.5G   0.01125  0.006421  0.001118        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.978      0.987      0.993      0.928
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      80/99     18.5G    0.0111  0.006756  0.001208        42       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.971      0.987      0.993      0.927
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      81/99     18.5G   0.01099  0.006717 0.0007379        44       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.978      0.985      0.993      0.928
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      82/99     18.5G   0.01073  0.006587  0.001125        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.98      0.987      0.993       0.93
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      83/99     18.5G   0.01121   0.00664  0.001048        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.973      0.992      0.993      0.931
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      84/99     18.5G    0.0114  0.006493  0.001092        35       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.981      0.987      0.993      0.932
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      85/99     18.5G   0.01082  0.006619 0.0007628        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905       0.98      0.989      0.993      0.931
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      86/99     18.5G   0.01039  0.006611 0.0008305        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.979      0.989      0.993      0.933
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      87/99     18.5G   0.01035  0.006231  0.001002        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.985      0.984      0.994      0.932
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      88/99     18.5G   0.01019  0.006487 0.0009479        42       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.978      0.979      0.993      0.928
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      89/99     18.5G   0.01048  0.006691 0.0005607        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.981      0.989      0.994      0.935
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      90/99     18.5G   0.01064   0.00636 0.0006455        40       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.981       0.99      0.994      0.935
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      91/99     18.5G   0.01072  0.006245  0.000459        31       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.984      0.986      0.994      0.936
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      92/99     18.5G   0.01065  0.006038  0.000882        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.981      0.991      0.994      0.938
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      93/99     18.5G   0.01028  0.006311 0.0004718        36       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.982       0.99      0.994      0.938
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      94/99     18.5G  0.009702  0.006005 0.0005453        37       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.985      0.988      0.994      0.938
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      95/99     18.5G  0.009896  0.006246 0.0006081        34       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.983      0.992      0.994      0.939
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      96/99     18.5G  0.009975  0.005882 0.0004531        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.985      0.989      0.994      0.939
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      97/99     18.5G   0.01098   0.00605 0.0004974        35       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.983      0.991      0.994       0.94
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      98/99     18.5G  0.009883  0.006237 0.0002429        39       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.984      0.991      0.994       0.94
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      99/99     18.5G  0.009929  0.006024 0.0003947        41       512: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.986      0.989      0.994      0.941
#
# 100 epochs completed in 1.490 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 173.1MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 173.1MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model Summary: 444 layers, 86186872 parameters, 0 gradients, 204.0 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3001       3905      0.986      0.989      0.994      0.942
#        fruit_healthy       3001       1637      0.969      0.977      0.992      0.968
#      fruit_woodiness       3001       1246      0.994      0.996      0.995      0.976
#      fruit_brownspot       3001       1022      0.996      0.994      0.995      0.881
# Results saved to runs/train/exp
# Destroying process group...

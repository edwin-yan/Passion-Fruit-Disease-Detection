# %%
import torch
print(f"Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
#Multi GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 8 train.py --img 512 --batch 640 --epochs 1500 --workers 120 --data passion_fruit.yaml --weights yolov5l.pt --sync-bn

#Multi GPU - from stratch
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 4 train.py --img 512 --batch 320 --epochs 1500 --workers 120 --data passion_fruit.yaml --weights '' --cfg yolov5l.yaml --hyp hyp.scratch-med.yaml --sync-bn
# !/home/shaohyan/anaconda3/envs/tf38/bin/python -m torch.distributed.launch --nproc_per_node 4 train.py --img 512 --batch 320 --epochs 1800 --workers 120 --data passion_fruit.yaml --weights '' --cfg yolov5l.yaml --hyp hyp.scratch.yaml --sync-bn


#Single GPU
# !/home/shaohyan/anaconda3/envs/tf38/bin/python train.py --img 512 --batch 32 --epochs 50 --data passion_fruit.yaml --weights yolov5s.pt
# Out:
# /home/shaohyan/anaconda3/envs/tf38/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# ...

# %% [markdown]
# **exp 2 -> Large model, 900 Epochs, default hyperparameter**
#
# !/home/shaohyan/anaconda3/envs/tf38/bin/python val.py --weights ./runs/train/exp2/weights/best.pt --data passion_fruit.yaml --img 512
#
# val: data=/home/shaohyan/.test/Passion-Fruit-Disease-Detection/Experiments/YOLOv5/data/passion_fruit.yaml, weights=['./runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 4d69baf torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Fusing layers...
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# Model Summary: 367 layers, 46119048 parameters, 0 gradients, 107.8 GFLOPs
# val: Scanning '../datasets/Val/labels.cache' images and labels... 303 found, 0 m
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.955      0.957       0.98      0.887
#        fruit_healthy        303        134      0.908      0.955      0.982       0.93
#      fruit_woodiness        303        124      0.983      0.958      0.975      0.941
#      fruit_brownspot        303        117      0.974      0.957      0.984      0.791
# Speed: 0.1ms pre-process, 416.5ms inference, 1.4ms NMS per image at shape (32, 3, 512, 512)
# Results saved to runs/val/exp5

# %% [markdown]
# **exp 3 -> Large model, 1500 Epochs, Med hyperparameter**
#
# !/home/shaohyan/anaconda3/envs/tf38/bin/python val.py --weights ./runs/train/exp3/weights/best.pt --data passion_fruit.yaml --img 512
#
# val: data=/home/shaohyan/.test/Passion-Fruit-Disease-Detection/Experiments/YOLOv5/data/passion_fruit.yaml, weights=['./runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 4d69baf torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Fusing layers...
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# Model Summary: 367 layers, 46119048 parameters, 0 gradients, 107.8 GFLOPs
# val: Scanning '../datasets/Val/labels.cache' images and labels... 303 found, 0 m
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.961      0.955      0.974      0.878
#        fruit_healthy        303        134      0.915      0.963      0.986       0.94
#      fruit_woodiness        303        124      0.977      0.935      0.961      0.916
#      fruit_brownspot        303        117       0.99      0.966      0.976      0.779
# Speed: 0.1ms pre-process, 415.0ms inference, 1.3ms NMS per image at shape (32, 3, 512, 512)
# Results saved to runs/val/exp4

# %% [markdown]
# **exp 4 -> Large model with Transformer, Med Hyper Parameter 1500 Epochs**
#
# !/home/shaohyan/anaconda3/envs/tf38/bin/python val.py --weights ./runs/train/exp4/weights/best.pt --data passion_fruit.yaml --img 512
#
#
# val: data=/home/shaohyan/.test/Passion-Fruit-Disease-Detection/Experiments/YOLOv5/data/passion_fruit.yaml, weights=['./runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 4d69baf torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Fusing layers...
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# Model Summary: 397 layers, 46090632 parameters, 0 gradients, 111.2 GFLOPs
# val: Scanning '../datasets/Val/labels.cache' images and labels... 303 found, 0 m
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.957      0.962      0.979      0.888
#        fruit_healthy        303        134       0.91      0.978      0.984       0.94
#      fruit_woodiness        303        124      0.983      0.958      0.968       0.93
#      fruit_brownspot        303        117      0.977      0.949      0.983      0.795
# Speed: 0.1ms pre-process, 426.1ms inference, 1.3ms NMS per image at shape (32, 3, 512, 512)
# Results saved to runs/val/exp

# %% [markdown]
# **exp 5 -> Large model, Transfer learning, Med Hyper Parameter 1500 Epochs**
#
#
# !/home/shaohyan/anaconda3/envs/tf38/bin/python val.py --weights ./runs/train/exp5/weights/best.pt --data passion_fruit.yaml --img 512
#
# val: data=/home/shaohyan/.test/Passion-Fruit-Disease-Detection/Experiments/YOLOv5/data/passion_fruit.yaml, weights=['./runs/train/exp5/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 4d69baf torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Fusing layers...
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# Model Summary: 367 layers, 46119048 parameters, 0 gradients, 107.8 GFLOPs
# val: Scanning '../datasets/Val/labels.cache' images and labels... 303 found, 0 m
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.953      0.957      0.978      0.875
#        fruit_healthy        303        134      0.897       0.97      0.982      0.923
#      fruit_woodiness        303        124      0.992      0.952      0.976      0.925
#      fruit_brownspot        303        117      0.972      0.949      0.977      0.779
# Speed: 0.1ms pre-process, 411.9ms inference, 1.2ms NMS per image at shape (32, 3, 512, 512)
# Results saved to runs/val/exp2

# %% [markdown]
# **exp 6 -> Large model, Transfer learning, Med Hyper Parameter 1500 Epochs**
#
# !/home/shaohyan/anaconda3/envs/tf38/bin/python val.py --weights ./runs/train/exp6/weights/best.pt --data passion_fruit.yaml --img 512
#
# val: data=/home/shaohyan/.test/Passion-Fruit-Disease-Detection/Experiments/YOLOv5/data/passion_fruit.yaml, weights=['./runs/train/exp6/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 4d69baf torch 1.9.1+rocm4.2 CUDA:0 (Device 738c, 32752.0MB)
#
# Fusing layers...
# MIOpen(HIP): Warning [SQLiteBase] Unable to read system database file:/opt/rocm/miopen/share/miopen/db/gfx90878.kdb Performance may degrade
# Model Summary: 367 layers, 46119048 parameters, 0 gradients, 107.8 GFLOPs
# val: Scanning '../datasets/Val/labels.cache' images and labels... 303 found, 0 m
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        303        375      0.974      0.928      0.961      0.865
#        fruit_healthy        303        134      0.947       0.94      0.972      0.921
#      fruit_woodiness        303        124      0.985      0.919       0.95       0.91
#      fruit_brownspot        303        117      0.991      0.926      0.962      0.762
# Speed: 0.1ms pre-process, 411.3ms inference, 1.2ms NMS per image at shape (32, 3, 512, 512)
# Results saved to runs/val/exp
